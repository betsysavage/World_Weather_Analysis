# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
from citipy import citipy

# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 729

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | acari
# Processing Record 4 of Set 1 | tabou
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | aberdeen
# Processing Record 7 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | dauphin
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | nador
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | hami
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 1 | lubango
# Processing Record 24 of Set 1 | churhat
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | erenhot
# Processing Record 27 of Set 1 | parabel
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | bairiki
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | dunedin
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | port-cartier
# Processing Record 39 of Set 1 | qiyang
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | la ronge
# Processing Record 43 of Set 1 | ketchikan
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | mackay
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | palmer
# Processing Record 50 of Set 1 | lata
# Processing Record 1 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | kargasok
# Processing Record 5 of Set 2 | tuatapere
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | bani
# Processing Record 8 of Set 2 | brake
# Processing Record 9 of Set 2 | langxiang
# Processing Record 10 of Set 2 | kodinsk
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | ambulu
# Processing Record 14 of Set 2 | half moon bay
# Processing Record 15 of Set 2 | khani
# Processing Record 16 of Set 2 | cape coast
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | cimarron hills
# Processing Record 21 of Set 2 | goderich
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | araouane
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | srednekolymsk
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | atyrau
# Processing Record 28 of Set 2 | svetlogorsk
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | kidal
# Processing Record 34 of Set 2 | kenora
# Processing Record 35 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 2 | itoman
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | lipari
# Processing Record 39 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 2 | vanimo
# Processing Record 41 of Set 2 | el tigre
# Processing Record 42 of Set 2 | narrabri
# Processing Record 43 of Set 2 | ust-nera
# Processing Record 44 of Set 2 | opotiki
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | hirado
# Processing Record 47 of Set 2 | hualmay
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | kautokeino
# Processing Record 50 of Set 2 | vardo
# Processing Record 1 of Set 3 | carmarthen
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | kalanguy
# Processing Record 4 of Set 3 | guerrero negro
# Processing Record 5 of Set 3 | nowa sol
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | pisco
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | faya
# Processing Record 13 of Set 3 | maragogi
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | enshi
# Processing Record 18 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | mantua
# Processing Record 21 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 3 | broken hill
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | octeville
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | takaka
# Processing Record 29 of Set 3 | morristown
# Processing Record 30 of Set 3 | batagay-alyta
# Processing Record 31 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | constitucion
# Processing Record 34 of Set 3 | casper
# Processing Record 35 of Set 3 | rocha
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | amurzet
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | capitao poco
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | verkhnevilyuysk
# Processing Record 44 of Set 3 | angra
# City not found. Skipping...
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | dawlatabad
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | inverell
# Processing Record 49 of Set 3 | west bay
# Processing Record 50 of Set 3 | harper
# Processing Record 1 of Set 4 | bereda
# Processing Record 2 of Set 4 | port hardy
# Processing Record 3 of Set 4 | linjiang
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | vestmannaeyjar
# Processing Record 6 of Set 4 | kenai
# Processing Record 7 of Set 4 | juneau
# Processing Record 8 of Set 4 | dingle
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | tyukhtet
# Processing Record 11 of Set 4 | zhezkazgan
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | magistralnyy
# Processing Record 15 of Set 4 | burriana
# Processing Record 16 of Set 4 | hammerfest
# Processing Record 17 of Set 4 | abu kamal
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | jalu
# Processing Record 22 of Set 4 | deputatskiy
# Processing Record 23 of Set 4 | moyale
# Processing Record 24 of Set 4 | panacan
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | akyab
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | roebourne
# Processing Record 29 of Set 4 | antofagasta
# Processing Record 30 of Set 4 | muroto
# Processing Record 31 of Set 4 | kumluca
# Processing Record 32 of Set 4 | tuy hoa
# Processing Record 33 of Set 4 | kloulklubed
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | atar
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | peleduy
# Processing Record 38 of Set 4 | mahibadhoo
# Processing Record 39 of Set 4 | celestun
# Processing Record 40 of Set 4 | kasempa
# Processing Record 41 of Set 4 | oksfjord
# Processing Record 42 of Set 4 | mogadishu
# Processing Record 43 of Set 4 | cap malheureux
# Processing Record 44 of Set 4 | san miguel
# Processing Record 45 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 4 | montana
# Processing Record 47 of Set 4 | champerico
# Processing Record 48 of Set 4 | chabahar
# Processing Record 49 of Set 4 | kirakira
# Processing Record 50 of Set 4 | palatka
# Processing Record 1 of Set 5 | sao filipe
# Processing Record 2 of Set 5 | hofn
# Processing Record 3 of Set 5 | coihaique
# Processing Record 4 of Set 5 | putina
# Processing Record 5 of Set 5 | maniitsoq
# Processing Record 6 of Set 5 | lakes entrance
# Processing Record 7 of Set 5 | lasa
# Processing Record 8 of Set 5 | gladstone
# Processing Record 9 of Set 5 | huarmey
# Processing Record 10 of Set 5 | chunskiy
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | bom jesus
# Processing Record 13 of Set 5 | qaanaaq
# Processing Record 14 of Set 5 | istanbul
# Processing Record 15 of Set 5 | varnavino
# Processing Record 16 of Set 5 | hailar
# Processing Record 17 of Set 5 | deoria
# Processing Record 18 of Set 5 | namatanai
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | paraiba do sul
# Processing Record 22 of Set 5 | saint-joseph
# Processing Record 23 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 5 | lamu
# Processing Record 25 of Set 5 | thunder bay
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | portland
# Processing Record 28 of Set 5 | hambantota
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | pampierstad
# Processing Record 31 of Set 5 | camapua
# Processing Record 32 of Set 5 | pishin
# Processing Record 33 of Set 5 | matamoros
# Processing Record 34 of Set 5 | homer
# Processing Record 35 of Set 5 | kaitangata
# Processing Record 36 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 5 | port blair
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | atakpame
# Processing Record 40 of Set 5 | padang
# Processing Record 41 of Set 5 | diego de almagro
# Processing Record 42 of Set 5 | sao felix do xingu
# Processing Record 43 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 5 | quixeramobim
# Processing Record 45 of Set 5 | mosquera
# Processing Record 46 of Set 5 | primorskiy
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | sakaraha
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | sahiwal
# Processing Record 1 of Set 6 | taoudenni
# Processing Record 2 of Set 6 | mizan teferi
# Processing Record 3 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 6 | awjilah
# Processing Record 6 of Set 6 | tolaga bay
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | davila
# Processing Record 9 of Set 6 | thompson
# Processing Record 10 of Set 6 | fonte boa
# Processing Record 11 of Set 6 | sivas
# Processing Record 12 of Set 6 | bikin
# Processing Record 13 of Set 6 | broome
# Processing Record 14 of Set 6 | yanam
# Processing Record 15 of Set 6 | arlit
# Processing Record 16 of Set 6 | cabra
# Processing Record 17 of Set 6 | papar
# Processing Record 18 of Set 6 | plettenberg bay
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | loding
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | bengkulu
# Processing Record 24 of Set 6 | atikokan
# Processing Record 25 of Set 6 | samana
# Processing Record 26 of Set 6 | alofi
# Processing Record 27 of Set 6 | pozo colorado
# Processing Record 28 of Set 6 | acapulco
# Processing Record 29 of Set 6 | orbetello
# Processing Record 30 of Set 6 | pochutla
# Processing Record 31 of Set 6 | peace river
# Processing Record 32 of Set 6 | baiyin
# Processing Record 33 of Set 6 | noumea
# Processing Record 34 of Set 6 | honiara
# Processing Record 35 of Set 6 | bonthe
# Processing Record 36 of Set 6 | canutama
# Processing Record 37 of Set 6 | chlorakas
# Processing Record 38 of Set 6 | benha
# City not found. Skipping...
# Processing Record 39 of Set 6 | aketi
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | puerto leguizamo
# Processing Record 42 of Set 6 | kolimvari
# City not found. Skipping...
# Processing Record 43 of Set 6 | narsaq
# Processing Record 44 of Set 6 | moree
# Processing Record 45 of Set 6 | tomatlan
# Processing Record 46 of Set 6 | paamiut
# Processing Record 47 of Set 6 | mayumba
# Processing Record 48 of Set 6 | touros
# Processing Record 49 of Set 6 | tabuk
# Processing Record 50 of Set 6 | mokhsogollokh
# Processing Record 1 of Set 7 | ampanihy
# Processing Record 2 of Set 7 | mezen
# Processing Record 3 of Set 7 | hithadhoo
# Processing Record 4 of Set 7 | atambua
# Processing Record 5 of Set 7 | kruisfontein
# Processing Record 6 of Set 7 | kingaroy
# Processing Record 7 of Set 7 | livingston
# Processing Record 8 of Set 7 | predivinsk
# Processing Record 9 of Set 7 | kizhinga
# Processing Record 10 of Set 7 | saldanha
# Processing Record 11 of Set 7 | hargeysa
# Processing Record 12 of Set 7 | arraial do cabo
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | puri
# Processing Record 15 of Set 7 | marrakesh
# Processing Record 16 of Set 7 | carbonia
# Processing Record 17 of Set 7 | coahuayana
# Processing Record 18 of Set 7 | matara
# Processing Record 19 of Set 7 | akdepe
# Processing Record 20 of Set 7 | beira
# Processing Record 21 of Set 7 | hastings
# Processing Record 22 of Set 7 | ye
# City not found. Skipping...
# Processing Record 23 of Set 7 | mitsamiouli
# Processing Record 24 of Set 7 | ponferrada
# Processing Record 25 of Set 7 | abu zabad
# Processing Record 26 of Set 7 | melipilla
# Processing Record 27 of Set 7 | kavaratti
# Processing Record 28 of Set 7 | zaltan
# Processing Record 29 of Set 7 | solok
# Processing Record 30 of Set 7 | yanliang
# Processing Record 31 of Set 7 | santiago
# Processing Record 32 of Set 7 | ornskoldsvik
# Processing Record 33 of Set 7 | balakhninskiy
# Processing Record 34 of Set 7 | at-bashi
# Processing Record 35 of Set 7 | manzhouli
# Processing Record 36 of Set 7 | gigmoto
# Processing Record 37 of Set 7 | grindavik
# Processing Record 38 of Set 7 | basco
# Processing Record 39 of Set 7 | katsuura
# Processing Record 40 of Set 7 | plastun
# Processing Record 41 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 42 of Set 7 | kalat
# Processing Record 43 of Set 7 | margate
# Processing Record 44 of Set 7 | cockburn town
# Processing Record 45 of Set 7 | ziro
# Processing Record 46 of Set 7 | ahipara
# Processing Record 47 of Set 7 | chirongui
# Processing Record 48 of Set 7 | tunxi
# City not found. Skipping...
# Processing Record 49 of Set 7 | tessalit
# Processing Record 50 of Set 7 | rio gallegos
# Processing Record 1 of Set 8 | neftcala
# Processing Record 2 of Set 8 | chicama
# Processing Record 3 of Set 8 | manavalakurichi
# Processing Record 4 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 8 | biala podlaska
# Processing Record 6 of Set 8 | chapais
# Processing Record 7 of Set 8 | nadym
# Processing Record 8 of Set 8 | makakilo city
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | fairbanks
# Processing Record 11 of Set 8 | olinda
# Processing Record 12 of Set 8 | vila franca do campo
# Processing Record 13 of Set 8 | wageningen
# Processing Record 14 of Set 8 | voyvozh
# Processing Record 15 of Set 8 | cortes
# Processing Record 16 of Set 8 | leshan
# Processing Record 17 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 8 | safranbolu
# Processing Record 20 of Set 8 | sambava
# Processing Record 21 of Set 8 | dodoma
# Processing Record 22 of Set 8 | saint-pierre
# Processing Record 23 of Set 8 | barabinsk
# Processing Record 24 of Set 8 | aginskoye
# Processing Record 25 of Set 8 | yar-sale
# Processing Record 26 of Set 8 | rawson
# Processing Record 27 of Set 8 | vila do maio
# Processing Record 28 of Set 8 | manokwari
# Processing Record 29 of Set 8 | katha
# City not found. Skipping...
# Processing Record 30 of Set 8 | aklavik
# Processing Record 31 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 8 | kunnamangalam
# Processing Record 33 of Set 8 | biak
# Processing Record 34 of Set 8 | grande prairie
# Processing Record 35 of Set 8 | kindu
# Processing Record 36 of Set 8 | porbandar
# Processing Record 37 of Set 8 | eyl
# Processing Record 38 of Set 8 | bali
# Processing Record 39 of Set 8 | badajoz
# Processing Record 40 of Set 8 | san cristobal
# Processing Record 41 of Set 8 | praia da vitoria
# Processing Record 42 of Set 8 | asau
# Processing Record 43 of Set 8 | lebyazhye
# Processing Record 44 of Set 8 | labytnangi
# Processing Record 45 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 8 | bainbridge
# Processing Record 47 of Set 8 | sabang
# Processing Record 48 of Set 8 | inta
# Processing Record 49 of Set 8 | san isidro
# Processing Record 50 of Set 8 | rwamagana
# Processing Record 1 of Set 9 | guanica
# Processing Record 2 of Set 9 | muli
# Processing Record 3 of Set 9 | kitimat
# Processing Record 4 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 5 of Set 9 | haicheng
# Processing Record 6 of Set 9 | sabaudia
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | saskylakh
# Processing Record 9 of Set 9 | whitianga
# Processing Record 10 of Set 9 | gambela
# Processing Record 11 of Set 9 | roura
# Processing Record 12 of Set 9 | tura
# Processing Record 13 of Set 9 | samarai
# Processing Record 14 of Set 9 | marquette
# Processing Record 15 of Set 9 | amapa
# Processing Record 16 of Set 9 | bumba
# Processing Record 17 of Set 9 | abha
# Processing Record 18 of Set 9 | chumikan
# Processing Record 19 of Set 9 | suntar
# Processing Record 20 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | polonnaruwa
# Processing Record 23 of Set 9 | disna
# Processing Record 24 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 25 of Set 9 | chipata
# Processing Record 26 of Set 9 | gewane
# Processing Record 27 of Set 9 | khovu-aksy
# Processing Record 28 of Set 9 | svetlaya
# Processing Record 29 of Set 9 | husavik
# Processing Record 30 of Set 9 | port pirie
# Processing Record 31 of Set 9 | rome
# Processing Record 32 of Set 9 | naters
# Processing Record 33 of Set 9 | pedernales
# Processing Record 34 of Set 9 | hirara
# Processing Record 35 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 9 | anadyr
# Processing Record 37 of Set 9 | lappeenranta
# Processing Record 38 of Set 9 | huambo
# Processing Record 39 of Set 9 | necochea
# Processing Record 40 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | westport
# Processing Record 43 of Set 9 | rudbar
# Processing Record 44 of Set 9 | severo-kurilsk
# Processing Record 45 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 9 | verkh-usugli
# Processing Record 47 of Set 9 | male
# Processing Record 48 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 9 | ixtapa
# Processing Record 50 of Set 9 | florence
# Processing Record 1 of Set 10 | misratah
# Processing Record 2 of Set 10 | khao yoi
# Processing Record 3 of Set 10 | sabla
# Processing Record 4 of Set 10 | dongli
# Processing Record 5 of Set 10 | kapustin yar
# Processing Record 6 of Set 10 | ayabaca
# Processing Record 7 of Set 10 | sinnai
# Processing Record 8 of Set 10 | saintes
# Processing Record 9 of Set 10 | corumba
# Processing Record 10 of Set 10 | yaan
# Processing Record 11 of Set 10 | yumen
# Processing Record 12 of Set 10 | geraldton
# Processing Record 13 of Set 10 | tilichiki
# Processing Record 14 of Set 10 | costa rica
# Processing Record 15 of Set 10 | huanan
# Processing Record 16 of Set 10 | eenhana
# Processing Record 17 of Set 10 | vao
# Processing Record 18 of Set 10 | shahrud
# Processing Record 19 of Set 10 | krasnoye
# Processing Record 20 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 10 | gorom-gorom
# Processing Record 22 of Set 10 | spokane
# Processing Record 23 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 10 | gemena
# Processing Record 25 of Set 10 | belmonte
# Processing Record 26 of Set 10 | mount isa
# Processing Record 27 of Set 10 | arman
# Processing Record 28 of Set 10 | benguela
# Processing Record 29 of Set 10 | lompoc
# Processing Record 30 of Set 10 | along
# Processing Record 31 of Set 10 | ucluelet
# Processing Record 32 of Set 10 | phan thiet
# Processing Record 33 of Set 10 | los llanos de aridane
# Processing Record 34 of Set 10 | lebanon
# Processing Record 35 of Set 10 | egvekinot
# Processing Record 36 of Set 10 | vaxjo
# Processing Record 37 of Set 10 | maarianhamina
# Processing Record 38 of Set 10 | garissa
# Processing Record 39 of Set 10 | tanjong sepat
# City not found. Skipping...
# Processing Record 40 of Set 10 | olafsvik
# Processing Record 41 of Set 10 | casas grandes
# Processing Record 42 of Set 10 | bandarbeyla
# Processing Record 43 of Set 10 | roma
# Processing Record 44 of Set 10 | namibe
# Processing Record 45 of Set 10 | mount gambier
# Processing Record 46 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 10 | kysyl-syr
# Processing Record 48 of Set 10 | signagi
# City not found. Skipping...
# Processing Record 49 of Set 10 | richards bay
# Processing Record 50 of Set 10 | la tuque
# Processing Record 1 of Set 11 | kahului
# Processing Record 2 of Set 11 | camacha
# Processing Record 3 of Set 11 | xinzhou
# Processing Record 4 of Set 11 | shediac
# Processing Record 5 of Set 11 | tiarei
# Processing Record 6 of Set 11 | tecoanapa
# Processing Record 7 of Set 11 | sao gabriel da cachoeira
# Processing Record 8 of Set 11 | bisira
# Processing Record 9 of Set 11 | kholtoson
# Processing Record 10 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | bonavista
# Processing Record 12 of Set 11 | pahrump
# Processing Record 13 of Set 11 | aden
# Processing Record 14 of Set 11 | xining
# Processing Record 15 of Set 11 | esperance
# Processing Record 16 of Set 11 | hasanabad
# Processing Record 17 of Set 11 | eureka
# Processing Record 18 of Set 11 | panguna
# Processing Record 19 of Set 11 | shache
# Processing Record 20 of Set 11 | mnogovershinnyy
# Processing Record 21 of Set 11 | muros
# Processing Record 22 of Set 11 | korla
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | lyuban
# Processing Record 25 of Set 11 | arroio grande
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | yunyang
# Processing Record 28 of Set 11 | taltal
# Processing Record 29 of Set 11 | nizhniy tsasuchey
# Processing Record 30 of Set 11 | nea vissa
# Processing Record 31 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 11 | berlevag
# Processing Record 33 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 11 | san quintin
# Processing Record 35 of Set 11 | namie
# Processing Record 36 of Set 11 | saint-augustin
# Processing Record 37 of Set 11 | mvuma
# Processing Record 38 of Set 11 | kidodi
# Processing Record 39 of Set 11 | omsukchan
# Processing Record 40 of Set 11 | dudinka
# Processing Record 41 of Set 11 | batemans bay
# Processing Record 42 of Set 11 | luwuk
# Processing Record 43 of Set 11 | nouadhibou
# Processing Record 44 of Set 11 | tezu
# Processing Record 45 of Set 11 | beringovskiy
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | santa cruz
# Processing Record 48 of Set 11 | borogontsy
# Processing Record 49 of Set 11 | desbiens
# Processing Record 50 of Set 11 | hobyo
# Processing Record 1 of Set 12 | balabac
# Processing Record 2 of Set 12 | bridgetown
# Processing Record 3 of Set 12 | bowen
# Processing Record 4 of Set 12 | navahrudak
# Processing Record 5 of Set 12 | ventspils
# Processing Record 6 of Set 12 | peniche
# Processing Record 7 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 12 | baker city
# Processing Record 9 of Set 12 | alta floresta
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | falun
# Processing Record 12 of Set 12 | odemira
# Processing Record 13 of Set 12 | dong hoi
# Processing Record 14 of Set 12 | labrea
# Processing Record 15 of Set 12 | kyrylivka
# Processing Record 16 of Set 12 | puerto del rosario
# Processing Record 17 of Set 12 | praia
# Processing Record 18 of Set 12 | shemursha
# Processing Record 19 of Set 12 | kisangani
# Processing Record 20 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 12 | omboue
# Processing Record 22 of Set 12 | mount hagen
# Processing Record 23 of Set 12 | gawler
# Processing Record 24 of Set 12 | mehamn
# Processing Record 25 of Set 12 | cogtong
# Processing Record 26 of Set 12 | zhovkva
# Processing Record 27 of Set 12 | drayton valley
# Processing Record 28 of Set 12 | varangaon
# Processing Record 29 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 12 | inuvik
# Processing Record 31 of Set 12 | imbituba
# Processing Record 32 of Set 12 | fengcheng
# Processing Record 33 of Set 12 | rantepao
# Processing Record 34 of Set 12 | tanout
# Processing Record 35 of Set 12 | biga
# Processing Record 36 of Set 12 | moroni
# Processing Record 37 of Set 12 | tonantins
# Processing Record 38 of Set 12 | miri
# Processing Record 39 of Set 12 | stepnogorsk
# Processing Record 40 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 12 | uige
# Processing Record 42 of Set 12 | laguna
# Processing Record 43 of Set 12 | russell
# Processing Record 44 of Set 12 | buala
# Processing Record 45 of Set 12 | jimma
# Processing Record 46 of Set 12 | chandur
# Processing Record 47 of Set 12 | kismayo
# Processing Record 48 of Set 12 | tyrma
# Processing Record 49 of Set 12 | brownsville
# Processing Record 50 of Set 12 | roswell
# Processing Record 1 of Set 13 | masalli
# Processing Record 2 of Set 13 | victoria point
# Processing Record 3 of Set 13 | sur
# Processing Record 4 of Set 13 | obuasi
# Processing Record 5 of Set 13 | west helena
# Processing Record 6 of Set 13 | mangochi
# Processing Record 7 of Set 13 | waddan
# Processing Record 8 of Set 13 | datong
# Processing Record 9 of Set 13 | phangnga
# Processing Record 10 of Set 13 | rivera
# Processing Record 11 of Set 13 | evensk
# Processing Record 12 of Set 13 | viedma
# Processing Record 13 of Set 13 | kyra
# Processing Record 14 of Set 13 | san vicente de canete
# Processing Record 15 of Set 13 | sylacauga
# Processing Record 16 of Set 13 | rock sound
# Processing Record 17 of Set 13 | chistogorskiy
# Processing Record 18 of Set 13 | abrau-dyurso
# Processing Record 19 of Set 13 | kholmogory
# Processing Record 20 of Set 13 | pokoynoye
# Processing Record 21 of Set 13 | lydenburg
# Processing Record 22 of Set 13 | zhuzhou
# Processing Record 23 of Set 13 | santarem
# Processing Record 24 of Set 13 | rincon
# Processing Record 25 of Set 13 | mitu
# Processing Record 26 of Set 13 | burica
# City not found. Skipping...
# Processing Record 27 of Set 13 | yerkoy
# Processing Record 28 of Set 13 | inirida
# Processing Record 29 of Set 13 | grand gaube
# Processing Record 30 of Set 13 | dakoro
# Processing Record 31 of Set 13 | torrington
# Processing Record 32 of Set 13 | anaconda
# Processing Record 33 of Set 13 | magadi
# Processing Record 34 of Set 13 | ossora
# Processing Record 35 of Set 13 | hoshcha
# Processing Record 36 of Set 13 | talaya
# Processing Record 37 of Set 13 | havre-saint-pierre
# Processing Record 38 of Set 13 | arsenyev
# Processing Record 39 of Set 13 | ghansor
# Processing Record 40 of Set 13 | galesong
# Processing Record 41 of Set 13 | smithers
# Processing Record 42 of Set 13 | aconibe
# Processing Record 43 of Set 13 | fort nelson
# Processing Record 44 of Set 13 | san andres
# Processing Record 45 of Set 13 | arroyo
# Processing Record 46 of Set 13 | pinheiro machado
# Processing Record 47 of Set 13 | nishihara
# Processing Record 48 of Set 13 | bonito oriental
# Processing Record 49 of Set 13 | mandalgovi
# Processing Record 50 of Set 13 | santa rosa
# Processing Record 1 of Set 14 | agirish
# Processing Record 2 of Set 14 | biryusinsk
# Processing Record 3 of Set 14 | ternate
# Processing Record 4 of Set 14 | maldonado
# Processing Record 5 of Set 14 | dali
# Processing Record 6 of Set 14 | san agustin
# Processing Record 7 of Set 14 | jizan
# Processing Record 8 of Set 14 | kasongo-lunda
# Processing Record 9 of Set 14 | port macquarie
# Processing Record 10 of Set 14 | birao
# Processing Record 11 of Set 14 | delogozdi
# City not found. Skipping...
# Processing Record 12 of Set 14 | vitim
# Processing Record 13 of Set 14 | poya
# Processing Record 14 of Set 14 | tongzi
# Processing Record 15 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 14 | vila velha
# Processing Record 17 of Set 14 | port lincoln
# Processing Record 18 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 14 | kaeo
# Processing Record 20 of Set 14 | charleston
# Processing Record 21 of Set 14 | shimoda
# Processing Record 22 of Set 14 | yerbogachen
# Processing Record 23 of Set 14 | aksu
# Processing Record 24 of Set 14 | novokayakent
# Processing Record 25 of Set 14 | san giovanni rotondo
# Processing Record 26 of Set 14 | khalkhal
# Processing Record 27 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 14 | gorgan
# Processing Record 29 of Set 14 | semey
# Processing Record 30 of Set 14 | malanje
# Processing Record 31 of Set 14 | ibotirama
# Processing Record 32 of Set 14 | wewak
# Processing Record 33 of Set 14 | mattru
# Processing Record 34 of Set 14 | arkadelphia
# Processing Record 35 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 14 | martapura
# Processing Record 37 of Set 14 | medak
# Processing Record 38 of Set 14 | teguldet
# Processing Record 39 of Set 14 | goreloye
# Processing Record 40 of Set 14 | taywarah
# Processing Record 41 of Set 14 | parnarama
# Processing Record 42 of Set 14 | nabire
# Processing Record 43 of Set 14 | feldbach
# Processing Record 44 of Set 14 | cascavel
# Processing Record 45 of Set 14 | mbanza-ngungu
# Processing Record 46 of Set 14 | heihe
# Processing Record 47 of Set 14 | malkangiri
# Processing Record 48 of Set 14 | riviere-au-renard
# Processing Record 49 of Set 14 | bam
# Processing Record 50 of Set 14 | boulsa
# Processing Record 1 of Set 15 | ulaangom
# Processing Record 2 of Set 15 | skjervoy
# Processing Record 3 of Set 15 | kroderen
# City not found. Skipping...
# Processing Record 4 of Set 15 | chongwe
# Processing Record 5 of Set 15 | kindersley
# Processing Record 6 of Set 15 | gamboma
# Processing Record 7 of Set 15 | haines junction
# Processing Record 8 of Set 15 | padre bernardo
# Processing Record 9 of Set 15 | garden city
# Processing Record 10 of Set 15 | hay river
# Processing Record 11 of Set 15 | kantunilkin
# Processing Record 12 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 15 | sanok
# Processing Record 14 of Set 15 | acarau
# Processing Record 15 of Set 15 | sunggal
# Processing Record 16 of Set 15 | chama
# Processing Record 17 of Set 15 | galeana
# Processing Record 18 of Set 15 | sinnamary
# Processing Record 19 of Set 15 | salalah
# Processing Record 20 of Set 15 | aykhal
# Processing Record 21 of Set 15 | taguatinga
# Processing Record 22 of Set 15 | mago
# Processing Record 23 of Set 15 | alice springs
# Processing Record 24 of Set 15 | komsomolskiy
# Processing Record 25 of Set 15 | willowmore
# Processing Record 26 of Set 15 | morehead
# Processing Record 27 of Set 15 | kopargaon
# Processing Record 28 of Set 15 | nome
# Processing Record 29 of Set 15 | kamenskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kodiak  57.7900 -152.4072     33.31        44           0
# 1          Hilo  19.7297 -155.0900     78.53        77          75
# 2         Acari -15.4311  -74.6158     71.69        76         100
# 3         Tabou   4.4230   -7.3528     78.24        81          89
# 4   Tuktoyaktuk  69.4541 -133.0374      3.20        78         100
# 5      Aberdeen  57.1437   -2.0981     22.50        86          13
# 6  Puerto Ayora  -0.7393  -90.3518     70.56        94          46
# 7       Rikitea -23.1203 -134.9692     75.85        79           6
# 8       Dauphin  51.1494 -100.0502     28.54        96         100
# 9        Torbay  47.6666  -52.7314     34.27        95         100
#
#    Wind Speed Country Current Description
# 0       17.27      US           clear sky
# 1        9.22      US       moderate rain
# 2        1.79      PE     overcast clouds
# 3        6.89      CI     overcast clouds
# 4       16.11      CA     overcast clouds
# 5        2.30      GB          few clouds
# 6        7.16      EC    scattered clouds
# 7       21.34      PF           clear sky
# 8        5.75      CA                mist
# 9        8.05      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kodiak      US  57.7900 -152.4072     33.31        44           0
# 1          Hilo      US  19.7297 -155.0900     78.53        77          75
# 2         Acari      PE -15.4311  -74.6158     71.69        76         100
# 3         Tabou      CI   4.4230   -7.3528     78.24        81          89
# 4   Tuktoyaktuk      CA  69.4541 -133.0374      3.20        78         100
# 5      Aberdeen      GB  57.1437   -2.0981     22.50        86          13
# 6  Puerto Ayora      EC  -0.7393  -90.3518     70.56        94          46
# 7       Rikitea      PF -23.1203 -134.9692     75.85        79           6
# 8       Dauphin      CA  51.1494 -100.0502     28.54        96         100
# 9        Torbay      CA  47.6666  -52.7314     34.27        95         100
#
#    Wind Speed Current Description
# 0       17.27           clear sky
# 1        9.22       moderate rain
# 2        1.79     overcast clouds
# 3        6.89     overcast clouds
# 4       16.11     overcast clouds
# 5        2.30          few clouds
# 6        7.16    scattered clouds
# 7       21.34           clear sky
# 8        5.75                mist
# 9        8.05     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
